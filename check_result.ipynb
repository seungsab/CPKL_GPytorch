# %%
import matplotlib.pyplot as plt


n_fnct = 3
sampling = 'lhs'
sampling = 'random'


fig, ax = plt.subplots(10, 3, figsize = (10, 2 * 10), dpi = 150, sharex=True, tight_layout=True)

for i in range(10):
    image = plt.imread(f'./result_per/fcnt{n_fnct}_random_seed_{i}.png')
    ax[i, 0].imshow(image)
    ax[i, 0].set_title('per')
    image = plt.imread(f'./result_per_cos/fcnt{n_fnct}_random_seed_{i}.png')
    ax[i, 1].imshow(image)
    ax[i, 1].set_title('per_cos')
    image = plt.imread(f'./result/fcnt{n_fnct}_random_seed_{i}.png')
    ax[i, 2].imshow(image)
    ax[i, 2].set_title('cos')

plt.show()
